# %% [markdown]
# # Cellucid Jupyter smoke test: real Pancreas data
#
# This short smoke test uses the Pancreas AnnData checked into `cellucid-python`. It verifies notebook embedding, a current UI command, a selection callback, and the structured connection report without relying on a private data path.
#
# Launch it from the repository root:
#
# ```bash
# python -m pip install -e . jupyterlab
# jupyter lab examples/jupyter_cellucid_smoketest.ipynb
# ```

# %%
from pathlib import Path

from cellucid import show_anndata

DATASET_RELATIVE_PATH = Path(
    "docs/user_guide/python_package/f_notebooks_tutorials/"
    "datasets/endocrinogenesis_day15.5_raw.h5ad"
)


def find_pancreas_h5ad(start: Path) -> Path:
    for base in (start.resolve(), *start.resolve().parents):
        candidate = base / DATASET_RELATIVE_PATH
        if candidate.is_file():
            return candidate
    raise FileNotFoundError(
        f"Missing checked-in tutorial dataset: {DATASET_RELATIVE_PATH}. "
        "Run this notebook from a clone of cellucid-python."
    )


DATA_PATH = find_pancreas_h5ad(Path.cwd())
DATA_PATH

# %%
viewer = show_anndata(
    DATA_PATH,
    height=650,
    dataset_name="Pancreatic endocrinogenesis (day 15.5)",
    dataset_id="pancreas-endocrinogenesis-day15-5",
)


@viewer.on_selection
def report_selection(event):
    cells = event.get("cells") or []
    print(f"Selected {len(cells)} cells")


viewer

# %%
viewer.wait_for_ready(timeout=120)
viewer.set_color_by("clusters")
viewer.highlight_cells([0, 1, 2], color="#E76F51")
viewer.state

# %%
report = viewer.debug_connection(timeout=10)
assert report["server_health"]["status"] == "ok"
report

# %%
viewer.stop()
